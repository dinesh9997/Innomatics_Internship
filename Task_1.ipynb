# %%
#1 question
u=input("enter user name: ")
p=input("enter password: ")
if u=="admin" and p=="1234":
  print("Login Successful")
else:
  print("Invalid Credentials")
# Out:
# enter user name: abcd
# enter password: 1234
# Invalid Credentials

# %%
#2
m=[45,78,90,33,60]
c=0
for i in m:
  if i>=50:
    c=c+1
print(f"Pass students:{c} & Fail students:{len(m)-c}")
# Out:
# Pass students:3 & Fail students:2

# %%
#3
s=[" Alice ","bob"," CHARLIE "]
n=len(s)
for i in range(n):
   s[i]=s[i].strip().lower()

print(s)
# Out:
# ['alice', 'bob', 'charlie']

# %%
#4
s=["Hi", "Welcome to the platform", "OK"]
for i in s:
  if len(i)>10:
     print(i ,"## flagged :",len(i),">10")
  else:
     print(i ,":",len(i))
# Out:
# Hi : 2
# Welcome to the platform ## flagged : 23 >10
# OK : 2

# %%
#5
s=["INFO", "ERROR", "WARNING", "ERROR"]
print(s.count("ERROR"))
# Out:
# 2
